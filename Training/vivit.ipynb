# %%
# !pip install -qq medmnist

# %%
# !pip install --upgrade keras
# !pip install albumentations

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/Bakis/cnnlstm/split.zip" -d "/content/dataset"
# Out:
# Archive:  /content/drive/MyDrive/Bakis/cnnlstm/split.zip
#   inflating: /content/dataset/training/labas/1-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/labas/2-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/labas/3-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/labas/4-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/labas/5-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/labas/6-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/labas/7-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/labas/8-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/labas/9-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/labas/10-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/labas/11-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/labas/12-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/labas/13-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/labas/14-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/labas/15-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/labas/16-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/labas/17-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/labas/18-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/labas/19-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/labas/20-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/labas/21-52aa9f42-bf3f-4fd3-bb4d-8da0f34279ea.webm
#   inflating: /content/dataset/training/labas/22-52aa9f42-bf3f-4fd3-bb4d-8da0f34279ea.webm
#   inflating: /content/dataset/training/labas/23-52aa9f42-bf3f-4fd3-bb4d-8da0f34279ea.webm
#   inflating: /content/dataset/training/labas/24-52aa9f42-bf3f-4fd3-bb4d-8da0f34279ea.webm
#   inflating: /content/dataset/training/labas/25-52aa9f42-bf3f-4fd3-bb4d-8da0f34279ea.webm
#   inflating: /content/dataset/training/labas/26-52aa9f42-bf3f-4fd3-bb4d-8da0f34279ea.webm
#   inflating: /content/dataset/training/labas/27-52aa9f42-bf3f-4fd3-bb4d-8da0f34279ea.webm
#   inflating: /content/dataset/training/labas/28-52aa9f42-bf3f-4fd3-bb4d-8da0f34279ea.webm
#   inflating: /content/dataset/training/labas/29-52aa9f42-bf3f-4fd3-bb4d-8da0f34279ea.webm
#   inflating: /content/dataset/training/labas/30-52aa9f42-bf3f-4fd3-bb4d-8da0f34279ea.webm
#   inflating: /content/dataset/training/labas/31-8f78d302-e926-4534-bfa4-09014a5ce6bd.webm
#   inflating: /content/dataset/training/labas/32-8f78d302-e926-4534-bfa4-09014a5ce6bd.webm
#   inflating: /content/dataset/training/labas/33-8f78d302-e926-4534-bfa4-09014a5ce6bd.webm
#   inflating: /content/dataset/training/labas/34-8f78d302-e926-4534-bfa4-09014a5ce6bd.webm
#   inflating: /content/dataset/training/labas/35-8f78d302-e926-4534-bfa4-09014a5ce6bd.webm
#   inflating: /content/dataset/training/labas/36-8f78d302-e926-4534-bfa4-09014a5ce6bd.webm
#   inflating: /content/dataset/training/labas/37-8f78d302-e926-4534-bfa4-09014a5ce6bd.webm
#   inflating: /content/dataset/training/labas/38-8f78d302-e926-4534-bfa4-09014a5ce6bd.webm
#   inflating: /content/dataset/training/labas/39-8f78d302-e926-4534-bfa4-09014a5ce6bd.webm
#   inflating: /content/dataset/training/labas/40-8f78d302-e926-4534-bfa4-09014a5ce6bd.webm
#   inflating: /content/dataset/training/labas/41-bc736f89-a0b3-4a2e-b136-3aaed60d17a6.webm
#   inflating: /content/dataset/training/labas/42-bc736f89-a0b3-4a2e-b136-3aaed60d17a6.webm
#   inflating: /content/dataset/training/labas/43-bc736f89-a0b3-4a2e-b136-3aaed60d17a6.webm
#   inflating: /content/dataset/training/labas/44-bc736f89-a0b3-4a2e-b136-3aaed60d17a6.webm
#   inflating: /content/dataset/training/labas/45-bc736f89-a0b3-4a2e-b136-3aaed60d17a6.webm
#   inflating: /content/dataset/training/labas/46-bc736f89-a0b3-4a2e-b136-3aaed60d17a6.webm
#   inflating: /content/dataset/training/labas/47-bc736f89-a0b3-4a2e-b136-3aaed60d17a6.webm
#   inflating: /content/dataset/training/labas/48-bc736f89-a0b3-4a2e-b136-3aaed60d17a6.webm
#   inflating: /content/dataset/training/labas/49-bc736f89-a0b3-4a2e-b136-3aaed60d17a6.webm
#   inflating: /content/dataset/training/labas/50-bc736f89-a0b3-4a2e-b136-3aaed60d17a6.webm
#   inflating: /content/dataset/training/labas/51-a540ca31-e026-4c47-907b-7a639d9fe46d.webm
#   inflating: /content/dataset/training/labas/52-a540ca31-e026-4c47-907b-7a639d9fe46d.webm
#   inflating: /content/dataset/training/labas/53-a540ca31-e026-4c47-907b-7a639d9fe46d.webm
#   inflating: /content/dataset/training/labas/54-a540ca31-e026-4c47-907b-7a639d9fe46d.webm
#   inflating: /content/dataset/training/labas/55-a540ca31-e026-4c47-907b-7a639d9fe46d.webm
#   inflating: /content/dataset/training/labas/56-a540ca31-e026-4c47-907b-7a639d9fe46d.webm
#   inflating: /content/dataset/training/labas/57-a540ca31-e026-4c47-907b-7a639d9fe46d.webm
#   inflating: /content/dataset/training/labas/58-a540ca31-e026-4c47-907b-7a639d9fe46d.webm
#   inflating: /content/dataset/training/labas/59-a540ca31-e026-4c47-907b-7a639d9fe46d.webm
#   inflating: /content/dataset/training/labas/60-a540ca31-e026-4c47-907b-7a639d9fe46d.webm
#   inflating: /content/dataset/training/labas/61-5243cbe0-39b2-4709-9336-e5e3a79ca905.webm
#   inflating: /content/dataset/training/labas/62-5243cbe0-39b2-4709-9336-e5e3a79ca905.webm
#   inflating: /content/dataset/training/labas/63-5243cbe0-39b2-4709-9336-e5e3a79ca905.webm
#   inflating: /content/dataset/training/labas/64-5243cbe0-39b2-4709-9336-e5e3a79ca905.webm
#   inflating: /content/dataset/training/labas/65-5243cbe0-39b2-4709-9336-e5e3a79ca905.webm
#   inflating: /content/dataset/training/labas/66-5243cbe0-39b2-4709-9336-e5e3a79ca905.webm
#   inflating: /content/dataset/training/labas/67-5243cbe0-39b2-4709-9336-e5e3a79ca905.webm
#   inflating: /content/dataset/training/labas/68-5243cbe0-39b2-4709-9336-e5e3a79ca905.webm
#   inflating: /content/dataset/training/labas/69-5243cbe0-39b2-4709-9336-e5e3a79ca905.webm
#   inflating: /content/dataset/training/labas/70-5243cbe0-39b2-4709-9336-e5e3a79ca905.webm
#   inflating: /content/dataset/training/labas/71-52e46305-9bd6-48b5-9c63-f71412327066.webm
#   inflating: /content/dataset/training/labas/72-52e46305-9bd6-48b5-9c63-f71412327066.webm
#   inflating: /content/dataset/training/labas/73-52e46305-9bd6-48b5-9c63-f71412327066.webm
#   inflating: /content/dataset/training/labas/74-52e46305-9bd6-48b5-9c63-f71412327066.webm
#   inflating: /content/dataset/training/labas/75-52e46305-9bd6-48b5-9c63-f71412327066.webm
#   inflating: /content/dataset/training/labas/76-52e46305-9bd6-48b5-9c63-f71412327066.webm
#   inflating: /content/dataset/training/labas/77-52e46305-9bd6-48b5-9c63-f71412327066.webm
#   inflating: /content/dataset/training/labas/78-52e46305-9bd6-48b5-9c63-f71412327066.webm
#   inflating: /content/dataset/training/labas/79-52e46305-9bd6-48b5-9c63-f71412327066.webm
#   inflating: /content/dataset/training/labas/80-52e46305-9bd6-48b5-9c63-f71412327066.webm
#   inflating: /content/dataset/training/labas/81-1a7e3a41-fa5f-4d48-88ca-87407c10c215.webm
#   inflating: /content/dataset/training/labas/82-1a7e3a41-fa5f-4d48-88ca-87407c10c215.webm
#   inflating: /content/dataset/training/labas/83-1a7e3a41-fa5f-4d48-88ca-87407c10c215.webm
#   inflating: /content/dataset/training/labas/84-1a7e3a41-fa5f-4d48-88ca-87407c10c215.webm
#   inflating: /content/dataset/training/labas/85-1a7e3a41-fa5f-4d48-88ca-87407c10c215.webm
#   inflating: /content/dataset/training/labas/86-1a7e3a41-fa5f-4d48-88ca-87407c10c215.webm
#   inflating: /content/dataset/training/labas/87-1a7e3a41-fa5f-4d48-88ca-87407c10c215.webm
#   inflating: /content/dataset/training/labas/88-1a7e3a41-fa5f-4d48-88ca-87407c10c215.webm
#   inflating: /content/dataset/training/labas/89-1a7e3a41-fa5f-4d48-88ca-87407c10c215.webm
#   inflating: /content/dataset/training/labas/90-1a7e3a41-fa5f-4d48-88ca-87407c10c215.webm
#   inflating: /content/dataset/training/labas/91-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/labas/92-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/labas/93-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/labas/94-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/labas/95-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/labas/96-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/labas/97-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/labas/98-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/labas/99-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/labas/100-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/labas/101-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/training/labas/102-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/training/labas/103-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/training/labas/104-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/training/labas/105-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/training/labas/106-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/training/labas/107-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/training/labas/108-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/training/labas/109-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/training/labas/110-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/validation/labas/111-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/validation/labas/112-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/validation/labas/113-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/validation/labas/114-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/validation/labas/115-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/validation/labas/116-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/validation/labas/117-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/validation/labas/118-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/validation/labas/119-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/validation/labas/120-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/test/labas/121-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/test/labas/122-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/test/labas/123-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/test/labas/124-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/test/labas/125-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/test/labas/126-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/test/labas/127-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/test/labas/128-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/test/labas/129-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/test/labas/130-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/validation/labas/131-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/validation/labas/132-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/validation/labas/133-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/validation/labas/134-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/validation/labas/135-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/validation/labas/136-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/validation/labas/137-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/validation/labas/138-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/validation/labas/139-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/validation/labas/140-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/test/labas/141-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/test/labas/142-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/test/labas/143-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/test/labas/144-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/test/labas/145-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/test/labas/146-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/test/labas/147-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/test/labas/148-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/test/labas/149-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/test/labas/150-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/training/labas/151-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/labas/152-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/labas/153-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/labas/154-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/labas/155-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/labas/156-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/labas/157-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/labas/158-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/labas/159-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/labas/160-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/labas/161-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/labas/162-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/labas/163-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/labas/164-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/labas/165-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/labas/166-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/labas/167-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/labas/168-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/labas/169-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/labas/170-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/labas/171-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/labas/172-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/labas/173-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/labas/174-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/labas/175-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/labas/176-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/labas/177-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/labas/178-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/labas/179-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/labas/180-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/labas/181-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/labas/182-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/labas/183-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/labas/184-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/labas/185-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/labas/186-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/labas/187-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/labas/188-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/labas/189-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/labas/190-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/labas/191-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/labas/192-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/labas/193-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/labas/194-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/labas/195-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/labas/196-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/labas/197-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/labas/198-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/labas/199-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/labas/200-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/labas/201-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/labas/202-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/labas/203-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/labas/204-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/labas/205-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/labas/206-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/labas/207-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/labas/208-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/labas/209-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/labas/210-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/labas/211-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/labas/212-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/labas/213-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/labas/214-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/labas/215-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/labas/216-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/labas/217-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/labas/218-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/labas/219-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/labas/220-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/labas/221-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/labas/222-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/labas/223-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/labas/224-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/labas/225-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/labas/226-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/labas/227-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/labas/228-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/labas/229-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/labas/230-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/labas/231-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/labas/232-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/labas/233-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/labas/234-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/labas/235-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/labas/236-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/labas/237-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/labas/238-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/labas/239-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/labas/240-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/labas/241-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm
#   inflating: /content/dataset/training/labas/242-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm
#   inflating: /content/dataset/training/labas/243-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm
#   inflating: /content/dataset/training/labas/244-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm
#   inflating: /content/dataset/training/labas/245-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm
#   inflating: /content/dataset/training/labas/246-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm
#   inflating: /content/dataset/training/labas/247-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm
#   inflating: /content/dataset/training/labas/248-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm
#   inflating: /content/dataset/training/labas/249-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm
#   inflating: /content/dataset/training/labas/250-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm
#   inflating: /content/dataset/training/mama/1-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/mama/2-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/mama/3-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/mama/4-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/mama/5-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/mama/6-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/mama/7-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/mama/8-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/mama/9-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/mama/10-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/mama/11-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/mama/12-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/mama/13-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/mama/14-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/mama/15-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/mama/16-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/mama/17-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/mama/18-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/mama/19-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/mama/20-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/mama/21-52aa9f42-bf3f-4fd3-bb4d-8da0f34279ea.webm
#   inflating: /content/dataset/training/mama/22-52aa9f42-bf3f-4fd3-bb4d-8da0f34279ea.webm
#   inflating: /content/dataset/training/mama/23-52aa9f42-bf3f-4fd3-bb4d-8da0f34279ea.webm
#   inflating: /content/dataset/training/mama/24-52aa9f42-bf3f-4fd3-bb4d-8da0f34279ea.webm
#   inflating: /content/dataset/training/mama/25-52aa9f42-bf3f-4fd3-bb4d-8da0f34279ea.webm
#   inflating: /content/dataset/training/mama/26-52aa9f42-bf3f-4fd3-bb4d-8da0f34279ea.webm
#   inflating: /content/dataset/training/mama/27-52aa9f42-bf3f-4fd3-bb4d-8da0f34279ea.webm
#   inflating: /content/dataset/training/mama/28-52aa9f42-bf3f-4fd3-bb4d-8da0f34279ea.webm
#   inflating: /content/dataset/training/mama/29-52aa9f42-bf3f-4fd3-bb4d-8da0f34279ea.webm
#   inflating: /content/dataset/training/mama/30-52aa9f42-bf3f-4fd3-bb4d-8da0f34279ea.webm
#   inflating: /content/dataset/training/mama/31-8f78d302-e926-4534-bfa4-09014a5ce6bd.webm
#   inflating: /content/dataset/training/mama/32-8f78d302-e926-4534-bfa4-09014a5ce6bd.webm
#   inflating: /content/dataset/training/mama/33-8f78d302-e926-4534-bfa4-09014a5ce6bd.webm
#   inflating: /content/dataset/training/mama/34-8f78d302-e926-4534-bfa4-09014a5ce6bd.webm
#   inflating: /content/dataset/training/mama/35-8f78d302-e926-4534-bfa4-09014a5ce6bd.webm
#   inflating: /content/dataset/training/mama/36-8f78d302-e926-4534-bfa4-09014a5ce6bd.webm
#   inflating: /content/dataset/training/mama/37-8f78d302-e926-4534-bfa4-09014a5ce6bd.webm
#   inflating: /content/dataset/training/mama/38-8f78d302-e926-4534-bfa4-09014a5ce6bd.webm
#   inflating: /content/dataset/training/mama/39-8f78d302-e926-4534-bfa4-09014a5ce6bd.webm
#   inflating: /content/dataset/training/mama/40-8f78d302-e926-4534-bfa4-09014a5ce6bd.webm
#   inflating: /content/dataset/training/mama/41-bc736f89-a0b3-4a2e-b136-3aaed60d17a6.webm
#   inflating: /content/dataset/training/mama/42-bc736f89-a0b3-4a2e-b136-3aaed60d17a6.webm
#   inflating: /content/dataset/training/mama/43-bc736f89-a0b3-4a2e-b136-3aaed60d17a6.webm
#   inflating: /content/dataset/training/mama/44-bc736f89-a0b3-4a2e-b136-3aaed60d17a6.webm
#   inflating: /content/dataset/training/mama/45-bc736f89-a0b3-4a2e-b136-3aaed60d17a6.webm
#   inflating: /content/dataset/training/mama/46-bc736f89-a0b3-4a2e-b136-3aaed60d17a6.webm
#   inflating: /content/dataset/training/mama/47-bc736f89-a0b3-4a2e-b136-3aaed60d17a6.webm
#   inflating: /content/dataset/training/mama/48-bc736f89-a0b3-4a2e-b136-3aaed60d17a6.webm
#   inflating: /content/dataset/training/mama/49-bc736f89-a0b3-4a2e-b136-3aaed60d17a6.webm
#   inflating: /content/dataset/training/mama/50-bc736f89-a0b3-4a2e-b136-3aaed60d17a6.webm
#   inflating: /content/dataset/training/mama/51-a540ca31-e026-4c47-907b-7a639d9fe46d.webm
#   inflating: /content/dataset/training/mama/52-a540ca31-e026-4c47-907b-7a639d9fe46d.webm
#   inflating: /content/dataset/training/mama/53-a540ca31-e026-4c47-907b-7a639d9fe46d.webm
#   inflating: /content/dataset/training/mama/54-a540ca31-e026-4c47-907b-7a639d9fe46d.webm
#   inflating: /content/dataset/training/mama/55-a540ca31-e026-4c47-907b-7a639d9fe46d.webm
#   inflating: /content/dataset/training/mama/56-a540ca31-e026-4c47-907b-7a639d9fe46d.webm
#   inflating: /content/dataset/training/mama/57-a540ca31-e026-4c47-907b-7a639d9fe46d.webm
#   inflating: /content/dataset/training/mama/58-a540ca31-e026-4c47-907b-7a639d9fe46d.webm
#   inflating: /content/dataset/training/mama/59-a540ca31-e026-4c47-907b-7a639d9fe46d.webm
#   inflating: /content/dataset/training/mama/60-a540ca31-e026-4c47-907b-7a639d9fe46d.webm
#   inflating: /content/dataset/training/mama/61-5243cbe0-39b2-4709-9336-e5e3a79ca905.webm
#   inflating: /content/dataset/training/mama/62-5243cbe0-39b2-4709-9336-e5e3a79ca905.webm
#   inflating: /content/dataset/training/mama/63-5243cbe0-39b2-4709-9336-e5e3a79ca905.webm
#   inflating: /content/dataset/training/mama/64-5243cbe0-39b2-4709-9336-e5e3a79ca905.webm
#   inflating: /content/dataset/training/mama/65-5243cbe0-39b2-4709-9336-e5e3a79ca905.webm
#   inflating: /content/dataset/training/mama/66-5243cbe0-39b2-4709-9336-e5e3a79ca905.webm
#   inflating: /content/dataset/training/mama/67-5243cbe0-39b2-4709-9336-e5e3a79ca905.webm
#   inflating: /content/dataset/training/mama/68-5243cbe0-39b2-4709-9336-e5e3a79ca905.webm
#   inflating: /content/dataset/training/mama/69-5243cbe0-39b2-4709-9336-e5e3a79ca905.webm
#   inflating: /content/dataset/training/mama/70-5243cbe0-39b2-4709-9336-e5e3a79ca905.webm
#   inflating: /content/dataset/training/mama/71-52e46305-9bd6-48b5-9c63-f71412327066.webm
#   inflating: /content/dataset/training/mama/72-52e46305-9bd6-48b5-9c63-f71412327066.webm
#   inflating: /content/dataset/training/mama/73-52e46305-9bd6-48b5-9c63-f71412327066.webm
#   inflating: /content/dataset/training/mama/74-52e46305-9bd6-48b5-9c63-f71412327066.webm
#   inflating: /content/dataset/training/mama/75-52e46305-9bd6-48b5-9c63-f71412327066.webm
#   inflating: /content/dataset/training/mama/76-52e46305-9bd6-48b5-9c63-f71412327066.webm
#   inflating: /content/dataset/training/mama/77-52e46305-9bd6-48b5-9c63-f71412327066.webm
#   inflating: /content/dataset/training/mama/78-52e46305-9bd6-48b5-9c63-f71412327066.webm
#   inflating: /content/dataset/training/mama/79-52e46305-9bd6-48b5-9c63-f71412327066.webm
#   inflating: /content/dataset/training/mama/80-52e46305-9bd6-48b5-9c63-f71412327066.webm
#   inflating: /content/dataset/training/mama/81-1a7e3a41-fa5f-4d48-88ca-87407c10c215.webm
#   inflating: /content/dataset/training/mama/82-1a7e3a41-fa5f-4d48-88ca-87407c10c215.webm
#   inflating: /content/dataset/training/mama/83-1a7e3a41-fa5f-4d48-88ca-87407c10c215.webm
#   inflating: /content/dataset/training/mama/84-1a7e3a41-fa5f-4d48-88ca-87407c10c215.webm
#   inflating: /content/dataset/training/mama/85-1a7e3a41-fa5f-4d48-88ca-87407c10c215.webm
#   inflating: /content/dataset/training/mama/86-1a7e3a41-fa5f-4d48-88ca-87407c10c215.webm
#   inflating: /content/dataset/training/mama/87-1a7e3a41-fa5f-4d48-88ca-87407c10c215.webm
#   inflating: /content/dataset/training/mama/88-1a7e3a41-fa5f-4d48-88ca-87407c10c215.webm
#   inflating: /content/dataset/training/mama/89-1a7e3a41-fa5f-4d48-88ca-87407c10c215.webm
#   inflating: /content/dataset/training/mama/90-1a7e3a41-fa5f-4d48-88ca-87407c10c215.webm
#   inflating: /content/dataset/training/mama/91-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/mama/92-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/mama/93-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/mama/94-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/mama/95-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/mama/96-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/mama/97-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/mama/98-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/mama/99-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/mama/100-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/mama/101-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/training/mama/102-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/training/mama/103-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/training/mama/104-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/training/mama/105-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/training/mama/106-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/training/mama/107-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/training/mama/108-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/training/mama/109-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/training/mama/110-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/validation/mama/111-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/validation/mama/112-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/validation/mama/113-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/validation/mama/114-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/validation/mama/115-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/validation/mama/116-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/validation/mama/117-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/validation/mama/118-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/validation/mama/119-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/validation/mama/120-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/test/mama/121-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/test/mama/122-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/test/mama/123-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/test/mama/124-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/test/mama/125-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/test/mama/126-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/test/mama/127-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/test/mama/128-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/test/mama/129-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/test/mama/130-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/validation/mama/131-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/validation/mama/132-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/validation/mama/133-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/validation/mama/134-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/validation/mama/135-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/validation/mama/136-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/validation/mama/137-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/validation/mama/138-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/validation/mama/139-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/validation/mama/140-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/test/mama/141-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/test/mama/142-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/test/mama/143-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/test/mama/144-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/test/mama/145-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/test/mama/146-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/test/mama/147-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/test/mama/148-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/test/mama/149-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/test/mama/150-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/training/mama/151-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/mama/152-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/mama/153-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/mama/154-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/mama/155-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/mama/156-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/mama/157-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/mama/158-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/mama/159-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/mama/160-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/mama/161-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/mama/162-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/mama/163-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/mama/164-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/mama/165-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/mama/166-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/mama/167-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/mama/168-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/mama/169-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/mama/170-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/mama/171-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/mama/172-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/mama/173-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/mama/174-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/mama/175-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/mama/176-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/mama/177-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/mama/178-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/mama/179-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/mama/180-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/mama/181-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/mama/182-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/mama/183-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/mama/184-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/mama/185-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/mama/186-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/mama/187-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/mama/188-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/mama/189-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/mama/190-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/mama/191-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/mama/192-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/mama/193-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/mama/194-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/mama/195-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/mama/196-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/mama/197-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/mama/198-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/mama/199-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/mama/200-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/mama/201-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/mama/202-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/mama/203-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/mama/204-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/mama/205-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/mama/206-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/mama/207-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/mama/208-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/mama/209-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/mama/210-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/mama/211-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/mama/212-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/mama/213-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/mama/214-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/mama/215-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/mama/216-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/mama/217-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/mama/218-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/mama/219-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/mama/220-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/mama/221-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/mama/222-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/mama/223-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/mama/224-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/mama/225-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/mama/226-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/mama/227-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/mama/228-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/mama/229-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/mama/230-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/mama/231-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/mama/232-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/mama/233-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/mama/234-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/mama/235-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/mama/236-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/mama/237-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/mama/238-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/mama/239-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/mama/240-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/mama/241-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm
#   inflating: /content/dataset/training/mama/242-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm
#   inflating: /content/dataset/training/mama/243-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm
#   inflating: /content/dataset/training/mama/244-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm
#   inflating: /content/dataset/training/mama/245-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm
#   inflating: /content/dataset/training/mama/246-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm
#   inflating: /content/dataset/training/mama/247-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm
#   inflating: /content/dataset/training/mama/248-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm
#   inflating: /content/dataset/training/mama/249-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm
#   inflating: /content/dataset/training/mama/250-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm
#   inflating: /content/dataset/training/kamuolys/1-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/kamuolys/2-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/kamuolys/3-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/kamuolys/4-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/kamuolys/5-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/kamuolys/6-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/kamuolys/7-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/kamuolys/8-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/kamuolys/9-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/kamuolys/10-653c0632-adc0-42be-8453-98dc71a55361.webm
#   inflating: /content/dataset/training/kamuolys/11-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/kamuolys/12-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/kamuolys/13-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/kamuolys/14-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/kamuolys/15-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/kamuolys/16-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/kamuolys/17-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/kamuolys/18-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/kamuolys/19-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/kamuolys/20-7aa54054-335a-4584-8a76-be8563eb1276.webm
#   inflating: /content/dataset/training/kamuolys/21-52aa9f42-bf3f-4fd3-bb4d-8da0f34279ea.webm
# ...
#   inflating: /content/dataset/training/berniukas/86-1a7e3a41-fa5f-4d48-88ca-87407c10c215.webm
#   inflating: /content/dataset/training/berniukas/87-1a7e3a41-fa5f-4d48-88ca-87407c10c215.webm
#   inflating: /content/dataset/training/berniukas/88-1a7e3a41-fa5f-4d48-88ca-87407c10c215.webm
#   inflating: /content/dataset/training/berniukas/89-1a7e3a41-fa5f-4d48-88ca-87407c10c215.webm
#   inflating: /content/dataset/training/berniukas/90-1a7e3a41-fa5f-4d48-88ca-87407c10c215.webm
#   inflating: /content/dataset/training/berniukas/91-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/berniukas/92-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/berniukas/93-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/berniukas/94-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/berniukas/95-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/berniukas/96-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/berniukas/97-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/berniukas/98-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/berniukas/99-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/berniukas/100-17069a48-e7a9-4333-9ab4-1275f424dc7b.webm
#   inflating: /content/dataset/training/berniukas/101-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/training/berniukas/102-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/training/berniukas/103-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/training/berniukas/104-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/training/berniukas/105-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/training/berniukas/106-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/training/berniukas/107-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/training/berniukas/108-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/training/berniukas/109-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/training/berniukas/110-473ceb7a-5ba4-48c5-abc4-abb206155879.webm
#   inflating: /content/dataset/validation/berniukas/111-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/validation/berniukas/112-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/validation/berniukas/113-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/validation/berniukas/114-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/validation/berniukas/115-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/validation/berniukas/116-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/validation/berniukas/117-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/validation/berniukas/118-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/validation/berniukas/119-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/validation/berniukas/120-09113db9-d512-442a-a399-65f4d75e26ac.webm
#   inflating: /content/dataset/test/berniukas/121-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/test/berniukas/122-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/test/berniukas/123-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/test/berniukas/124-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/test/berniukas/125-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/test/berniukas/126-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/test/berniukas/127-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/test/berniukas/128-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/test/berniukas/129-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/test/berniukas/130-5487abbd-1ce4-4d43-a8ec-affc6ddecb1a.webm
#   inflating: /content/dataset/validation/berniukas/131-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/validation/berniukas/132-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/validation/berniukas/133-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/validation/berniukas/134-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/validation/berniukas/135-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/validation/berniukas/136-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/validation/berniukas/137-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/validation/berniukas/138-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/validation/berniukas/139-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/validation/berniukas/140-dc71d28c-0e13-45e0-8fbe-987d35bd0a2a.webm
#   inflating: /content/dataset/test/berniukas/141-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/test/berniukas/142-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/test/berniukas/143-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/test/berniukas/144-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/test/berniukas/145-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/test/berniukas/146-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/test/berniukas/147-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/test/berniukas/148-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/test/berniukas/149-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/test/berniukas/150-e5ce3f72-ee92-45ee-8ff1-c6626796a843.webm
#   inflating: /content/dataset/training/berniukas/151-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/berniukas/152-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/berniukas/153-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/berniukas/154-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/berniukas/155-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/berniukas/156-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/berniukas/157-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/berniukas/158-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/berniukas/159-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/berniukas/160-1afe7749-6561-4c20-ab3f-a100c384daad.webm
#   inflating: /content/dataset/training/berniukas/161-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/berniukas/162-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/berniukas/163-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/berniukas/164-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/berniukas/165-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/berniukas/166-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/berniukas/167-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/berniukas/168-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/berniukas/169-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/berniukas/170-73dc2424-e578-4e09-a2c5-b588f3049ad1.webm
#   inflating: /content/dataset/training/berniukas/171-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/berniukas/172-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/berniukas/173-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/berniukas/174-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/berniukas/175-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/berniukas/176-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/berniukas/177-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/berniukas/178-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/berniukas/179-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/berniukas/180-257f8667-0610-46a8-8597-d3cc0755c710.webm
#   inflating: /content/dataset/training/berniukas/181-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/berniukas/182-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/berniukas/183-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/berniukas/184-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/berniukas/185-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/berniukas/186-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/berniukas/187-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/berniukas/188-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/berniukas/189-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/berniukas/190-ed02a7af-1e6f-4d5a-a4f6-47aaa4e59e9d.webm
#   inflating: /content/dataset/training/berniukas/191-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/berniukas/192-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/berniukas/193-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/berniukas/194-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/berniukas/195-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/berniukas/196-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/berniukas/197-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/berniukas/198-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/berniukas/199-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/berniukas/200-93ccfc72-ecc9-4239-a20f-a2289336c75b.webm
#   inflating: /content/dataset/training/berniukas/201-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/berniukas/202-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/berniukas/203-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/berniukas/204-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/berniukas/205-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/berniukas/206-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/berniukas/207-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/berniukas/208-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/berniukas/209-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/berniukas/210-bfb28965-9537-4c2e-9c56-1eecae5890d2.webm
#   inflating: /content/dataset/training/berniukas/211-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/berniukas/212-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/berniukas/213-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/berniukas/214-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/berniukas/215-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/berniukas/216-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/berniukas/217-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/berniukas/218-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/berniukas/219-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/berniukas/220-2147fdf1-ec22-45f5-9153-643cb1a8cd34.webm
#   inflating: /content/dataset/training/berniukas/221-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/berniukas/222-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/berniukas/223-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/berniukas/224-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/berniukas/225-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/berniukas/226-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/berniukas/227-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/berniukas/228-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/berniukas/229-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/berniukas/230-35ecf95a-9e6f-4838-8cef-caa069c753d9.webm
#   inflating: /content/dataset/training/berniukas/231-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/berniukas/232-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/berniukas/233-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/berniukas/234-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/berniukas/235-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/berniukas/236-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/berniukas/237-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/berniukas/238-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/berniukas/239-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/berniukas/240-031c0ff6-628e-4659-bbbb-76e404495bfc.webm
#   inflating: /content/dataset/training/berniukas/241-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm
#   inflating: /content/dataset/training/berniukas/242-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm
#   inflating: /content/dataset/training/berniukas/243-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm
#   inflating: /content/dataset/training/berniukas/244-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm
#   inflating: /content/dataset/training/berniukas/245-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm
#   inflating: /content/dataset/training/berniukas/246-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm
#   inflating: /content/dataset/training/berniukas/247-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm
#   inflating: /content/dataset/training/berniukas/248-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm
#   inflating: /content/dataset/training/berniukas/249-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm
#   inflating: /content/dataset/training/berniukas/250-2cca7e9a-71ab-448e-ab6c-7e07046d66a9.webm

# %%
import os
import io
import imageio
import pandas as pd
import ipywidgets
import numpy as np
import tensorflow as tf  # for data preprocessing only
import keras
from keras import layers, ops
import cv2
from sklearn.preprocessing import LabelEncoder
import albumentations as A
import random

# %%
grab_frames = 30
target_shape = 160

# %%
train_dir = '/content/dataset/training'
test_dir = '/content/dataset/test'
val_dir = '/content/dataset/validation'

# %%
labels = np.array(['aciu', 'berniukas', 'kamuolys', 'koks', 'labas', 'mama', 'namas', 'tevas', 'valgyti', 'vardas'])

# %%
def process_dataset(train_dir, set_size, augment=False):
    X_data = np.zeros((set_size, grab_frames, target_shape, target_shape, 3), dtype=np.uint8)
    y_temp = np.zeros((set_size,), dtype=object)

    index = 0
    random.seed(7)

    transform = A.ReplayCompose([
      A.HorizontalFlip(p=0.5),
      A.MotionBlur(blur_limit=5, p=0.3),
      A.ShiftScaleRotate(shift_limit=0.02, scale_limit=0.02, rotate_limit=10, p=0.5),
      A.RandomBrightnessContrast(brightness_limit=0.1, contrast_limit=0.1, p=0.4),
      A.CLAHE(clip_limit=2, p=0.3),
      A.HueSaturationValue(hue_shift_limit=10, sat_shift_limit=20, val_shift_limit=10, p=0.3),
      A.ISONoise(color_shift=(0.01, 0.03), intensity=(0.1, 0.3), p=0.3),
    ])

    data = []

    source_directory = os.path.abspath(train_dir)
    sub_folders = os.listdir(source_directory)

    for folder in sub_folders:
        folder_path = os.path.join(source_directory, folder)
        files = os.listdir(folder_path)

        for file in files:

            video_path = os.path.join(folder_path, file)
            video = cv2.VideoCapture(video_path)
            frames = []
            framesAug = []
            count = 1
            lastFrame = None
            skip = False

            while count <= grab_frames:
                ret, frame = video.read()
                if not ret:
                    break

                if skip == True:
                  skip = not skip
                  continue

                frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                frame = cv2.resize(frame, (target_shape, target_shape))
                lastFrame = frame

                if augment != True:
                  frames.append(frame)

                count += 1

                if augment:
                  if data == []:
                    data = transform(image=frame)
                    framesAug.append(data['image'])
                  else:
                    augImg = A.ReplayCompose.replay(data['replay'], image=frame)
                    framesAug.append(augImg['image'])

                skip = not skip

            video.release()
            cv2.destroyAllWindows()

            if augment != True:
              X_data[index] = np.array(frames)
              y_temp[index] = folder
              index += 1
            if augment:
              X_data[index] = np.array(framesAug)
              y_temp[index] = folder
              index += 1
              data = []
            print(index)


    return X_data, y_temp

# %%
X_train, y_train = process_dataset(train_dir, 2100, True)

# %%
X_valid, y_valid = process_dataset(val_dir, 200)

# %%
X_test, y_test = process_dataset(test_dir, 200)

# %%
le = LabelEncoder()

# Fit the encoder on the labels array
le.fit(labels)  # Learning the mapping from the labels array

# Transform the dataset using the learned encoder
y_train = le.transform(y_train)
y_valid = le.transform(y_valid)
y_test = le.transform(y_test)

# %%
SEED = 42
os.environ["TF_CUDNN_DETERMINISTIC"] = "1"
keras.utils.set_random_seed(SEED)

# %%
BATCH_SIZE = 128
AUTO = tf.data.AUTOTUNE
INPUT_SHAPE = (grab_frames, target_shape, target_shape, 3)
NUM_CLASSES = 10

# OPTIMIZER
LEARNING_RATE = 0.0001
# WEIGHT_DECAY = 1e-5

# TRAINING
EPOCHS = 1000

# TUBELET EMBEDDING
PATCH_SIZE = (16, 16, 16)
NUM_PATCHES = (INPUT_SHAPE[0] // PATCH_SIZE[0]) ** 2

# ViViT ARCHITECTURE
LAYER_NORM_EPS = 1e-6
PROJECTION_DIM = 128
NUM_HEADS = 8
NUM_LAYERS = 8

# %%
def preprocess(frames: tf.Tensor, label: tf.Tensor):
    """Preprocess the frames tensors and parse the labels."""
    # Preprocess images
    frames = tf.image.convert_image_dtype(
        frames[
            ..., tf.newaxis
        ],  # The new axis is to help for further processing with Conv3D layers
        tf.float32,
    )
    # Parse label
    label = tf.cast(label, tf.float32)
    return frames, label


def prepare_dataloader(
    videos: np.ndarray,
    labels: np.ndarray,
    loader_type: str = "train",
    batch_size: int = BATCH_SIZE,
):
    """Utility function to prepare the dataloader."""
    dataset = tf.data.Dataset.from_tensor_slices((videos, labels))

    if loader_type == "train":
        dataset = dataset.shuffle(BATCH_SIZE * 2)

    dataloader = (
        dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
        .batch(batch_size)
        .prefetch(tf.data.AUTOTUNE)
    )
    return dataloader

# %%
X_train_loader = prepare_dataloader(X_train, y_train, "train")

# %%
X_valid_loader = prepare_dataloader(X_valid, y_valid, "valid")

# %%
X_test_loader = prepare_dataloader(X_test, y_valid, "test")

# %%
X_train = []
y_train = []
X_valid = []
y_valid = []
X_test = []
y_test = []

# %%
class TubeletEmbedding(layers.Layer):
    def __init__(self, embed_dim, patch_size, **kwargs):
        super().__init__(**kwargs)
        self.projection = layers.Conv3D(
            filters=embed_dim,
            kernel_size=patch_size,
            strides=patch_size,
            padding="VALID",
        )
        self.flatten = layers.Reshape(target_shape=(-1, embed_dim))

    def call(self, videos):
        projected_patches = self.projection(videos)
        flattened_patches = self.flatten(projected_patches)
        return flattened_patches

# %%
class PositionalEncoder(layers.Layer):
    def __init__(self, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim

    def build(self, input_shape):
        _, num_tokens, _ = input_shape
        self.position_embedding = layers.Embedding(
            input_dim=num_tokens, output_dim=self.embed_dim
        )
        self.positions = ops.arange(0, num_tokens, 1)

    def call(self, encoded_tokens):
        # Encode the positions and add it to the encoded tokens
        encoded_positions = self.position_embedding(self.positions)
        encoded_tokens = encoded_tokens + encoded_positions
        return encoded_tokens

# %%
def create_vivit_classifier(
    tubelet_embedder,
    positional_encoder,
    input_shape=INPUT_SHAPE,
    transformer_layers=NUM_LAYERS,
    num_heads=NUM_HEADS,
    embed_dim=PROJECTION_DIM,
    layer_norm_eps=LAYER_NORM_EPS,
    num_classes=NUM_CLASSES,
):
    # Get the input layer
    inputs = layers.Input(shape=input_shape)
    # Create patches.
    patches = tubelet_embedder(inputs)
    # Encode patches.
    encoded_patches = positional_encoder(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization and MHSA
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim // num_heads, dropout=0.1
        )(x1, x1)

        # Skip connection
        x2 = layers.Add()([attention_output, encoded_patches])

        # Layer Normalization and MLP
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        x3 = keras.Sequential(
            [
                layers.Dense(units=embed_dim * 4, activation=ops.gelu),
                layers.Dense(units=embed_dim, activation=ops.gelu),
            ]
        )(x3)

        # Skip connection
        encoded_patches = layers.Add()([x3, x2])

    # Layer normalization and Global average pooling.
    representation = layers.LayerNormalization(epsilon=layer_norm_eps)(encoded_patches)
    representation = layers.GlobalAvgPool1D()(representation)

    # Classify outputs.
    outputs = layers.Dense(units=num_classes, activation="softmax")(representation)

    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %%
def run_experiment():
    # Initialize model
    model = create_vivit_classifier(
        tubelet_embedder=TubeletEmbedding(
            embed_dim=PROJECTION_DIM, patch_size=PATCH_SIZE
        ),
        positional_encoder=PositionalEncoder(embed_dim=PROJECTION_DIM),
    )

    # Compile the model with the optimizer, loss function
    # and the metrics.
    optimizer = keras.optimizers.Adam(learning_rate=LEARNING_RATE)
    model.compile(
        optimizer=optimizer,
        loss="sparse_categorical_crossentropy",
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
        ],
    )

    # Train the model.
    history = model.fit(X_train_loader, epochs=EPOCHS, validation_data=X_valid_loader)

    hist = pd.DataFrame(history.history)
    plot = hist.plot()
    plot.figure.savefig("/content/drive/MyDrive/Bakis/vivit/train.jpg")

    eval = model.evaluate(X_test_loader)

    return model

# %%
model = run_experiment()
model.save("/content/drive/MyDrive/Bakis/vivit/model.h5")

# %%
from google.colab import runtime
runtime.unassign()
